// %%
%use kandy
%use dataframe
%use lets-plot
// Out:
//    <div id="T5SgkX"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("T5SgkX").appendChild(div);
//            };
//            var e = document.getElementById("T5SgkX");
//            e.appendChild(script);
//        })();
//    </script>

// %%
val url = "http://192.168.35.107:7788/khnp/wastewater"
val df = DataFrame.readJson(url)
df.head(5)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_117440592"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 6</p>
// <table class="dataframe" id="static_df_117440593"><thead><tr><th class="bottomBorder" style="text-align:left">time</th><th class="bottomBorder" style="text-align:left">genName</th><th class="bottomBorder" style="text-align:left">tm001</th><th class="bottomBorder" style="text-align:left">tm001_time</th><th class="bottomBorder" style="text-align:left">tm002</th><th class="bottomBorder" style="text-align:left">tm002_time</th></tr></thead><tbody><tr><td  style="vertical-align:top">2026-04-22 11:21</td><td  style="vertical-align:top">KR</td><td  style="vertical-align:top">0.0</td><td  style="vertical-align:top">2026-04-22 11:20</td><td  style="vertical-align:top">7.300000190734863</td><td  style="vertical-align:top">2026-04-22 11:20</td></tr><tr><td  style="vertical-align:top">2026-04-22 11:21</td><td  style="vertical-align:top">WS</td><td  style="vertical-align:top">40.8</td><td  style="vertical-align:top">2026-04-22 11:20</td><td  style="vertical-align:top">7.1</td><td  style="vertical-align:top">2026-04-22 11:20</td></tr><tr><td  style="vertical-align:top">2026-04-22 11:21</td><td  style="vertical-align:top">YK</td><td  style="vertical-align:top">0</td><td  style="vertical-align:top">2026-03-30 06:58</td><td  style="vertical-align:top">0</td><td  style="vertical-align:top">2026-03-30 06:58</td></tr><tr><td  style="vertical-align:top">2026-04-22 11:24</td><td  style="vertical-align:top">KR</td><td  style="vertical-align:top">0.0</td><td  style="vertical-align:top">2026-04-22 11:23</td><td  style="vertical-align:top">7.300000190734

// %%
import kotlin.math.round

val convertValueDf = df.convert { tm001 and tm002 }.with {
    val value = it?.toString()?.toDoubleOrNull() ?: 0.0
    round(value * 10) / 10.0
}
convertValueDf.head(5)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_117440594"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 6</p>
// <table class="dataframe" id="static_df_117440595"><thead><tr><th class="bottomBorder" style="text-align:left">time</th><th class="bottomBorder" style="text-align:left">genName</th><th class="bottomBorder" style="text-align:left">tm001</th><th class="bottomBorder" style="text-align:left">tm001_time</th><th class="bottomBorder" style="text-align:left">tm002</th><th class="bottomBorder" style="text-align:left">tm002_time</th></tr></thead><tbody><tr><td  style="vertical-align:top">2026-04-22 11:21</td><td  style="vertical-align:top">KR</td><td  style="vertical-align:top">0.000000</td><td  style="vertical-align:top">2026-04-22 11:20</td><td  style="vertical-align:top">7.300000</td><td  style="vertical-align:top">2026-04-22 11:20</td></tr><tr><td  style="vertical-align:top">2026-04-22 11:21</td><td  style="vertical-align:top">WS</td><td  style="vertical-align:top">40.800000</td><td  style="vertical-align:top">2026-04-22 11:20</td><td  style="vertical-align:top">7.100000</td><td  style="vertical-align:top">2026-04-22 11:20</td></tr><tr><td  style="vertical-align:top">2026-04-22 11:21</td><td  style="vertical-align:top">YK</td><td  style="vertical-align:top">0.000000</td><td  style="vertical-align:top">2026-03-30 06:58</td><td  style="vertical-align:top">0.000000</td><td  style="vertical-align:top">2026-03-30 06:58</td></tr><tr><td  style="vertical-align:top">2026-04-22 11:24</td><td  style="vertical-align:top">KR</td><td  style="vertical-align:top">0.000000</td><td  style="vertical-align:top">2026-04-22 11:23</td><td  style="vertical-

// %%
import kotlinx.datetime.*
import kotlin.time.Duration.Companion.minutes

val convertTimeDf = convertValueDf.convert {
    time and tm001_time and tm002_time
}.with { 
    LocalDateTime.parse(it.toString().replace(" ", "T")).toInstant(TimeZone.UTC)
}

convertTimeDf.head(5)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_117440596"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 6</p>
// <table class="dataframe" id="static_df_117440597"><thead><tr><th class="bottomBorder" style="text-align:left">time</th><th class="bottomBorder" style="text-align:left">genName</th><th class="bottomBorder" style="text-align:left">tm001</th><th class="bottomBorder" style="text-align:left">tm001_time</th><th class="bottomBorder" style="text-align:left">tm002</th><th class="bottomBorder" style="text-align:left">tm002_time</th></tr></thead><tbody><tr><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">KR</td><td  style="vertical-align:top">0.000000</td><td  style="vertical-align:top">2026-04-22T11:20:00Z</td><td  style="vertical-align:top">7.300000</td><td  style="vertical-align:top">2026-04-22T11:20:00Z</td></tr><tr><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">WS</td><td  style="vertical-align:top">40.800000</td><td  style="vertical-align:top">2026-04-22T11:20:00Z</td><td  style="vertical-align:top">7.100000</td><td  style="vertical-align:top">2026-04-22T11:20:00Z</td></tr><tr><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">YK</td><td  style="vertical-align:top">0.000000</td><td  style="vertical-align:top">2026-03-30T06:58:00Z</td><td  style="vertical-align:top">0.000000</td><td  style="vertical-align:top">2026-03-30T06:58:00Z</td></tr><tr><td  style="vertical-align:top">2026-04-22T11:24:00Z</td><td  style="vertical-align:top">KR</td><td  style="vertical-align:top">0.000000</td><td  style="vertical-align:top">20

// %%
val checkTime = 10.minutes

val finalDf = convertTimeDf.filter {
    (time - tm001_time).absoluteValue <= checkTime &&
    (time - tm002_time).absoluteValue <= checkTime 
}
finalDf.head(5)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_117440600"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 6</p>
// <table class="dataframe" id="static_df_117440601"><thead><tr><th class="bottomBorder" style="text-align:left">time</th><th class="bottomBorder" style="text-align:left">genName</th><th class="bottomBorder" style="text-align:left">tm001</th><th class="bottomBorder" style="text-align:left">tm001_time</th><th class="bottomBorder" style="text-align:left">tm002</th><th class="bottomBorder" style="text-align:left">tm002_time</th></tr></thead><tbody><tr><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">KR</td><td  style="vertical-align:top">0.000000</td><td  style="vertical-align:top">2026-04-22T11:20:00Z</td><td  style="vertical-align:top">7.300000</td><td  style="vertical-align:top">2026-04-22T11:20:00Z</td></tr><tr><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">WS</td><td  style="vertical-align:top">40.800000</td><td  style="vertical-align:top">2026-04-22T11:20:00Z</td><td  style="vertical-align:top">7.100000</td><td  style="vertical-align:top">2026-04-22T11:20:00Z</td></tr><tr><td  style="vertical-align:top">2026-04-22T11:24:00Z</td><td  style="vertical-align:top">KR</td><td  style="vertical-align:top">0.000000</td><td  style="vertical-align:top">2026-04-22T11:23:00Z</td><td  style="vertical-align:top">7.300000</td><td  style="vertical-align:top">2026-04-22T11:23:00Z</td></tr><tr><td  style="vertical-align:top">2026-04-22T11:24:00Z</td><td  style="vertical-align:top">WS</td><td  style="vertical-align:top">40.800000</td><td  style="vertical-align:top">2

// %%
//letsPlot( finalDf.filter{ time >= "2026-04-21 22:00" }.toMap() ) +
letsPlot( finalDf.toMap() ) +
labs( title = "분단위 실시간 폐수 수질현황", y="Wastewater Quality (PH)", x="수집시간", color="발전소") +     
geomPoint( alpha = 0.6){
    x = "time";
    y = "tm002";
    color="genName";
    size="tm001";
} +
scaleYContinuous(limits=Pair(5.0,9.0)) +
// %Y: 년, %m: 월, %d: 일, %H: 시, %M: 분
scaleXDateTime(
    format = "%m-%d %H:%M" 
) +
scaleSize(range=Pair(0, 15), name="유량") +
theme(
    axisTextX= elementText( angle=45, hjust = 1.0),
) +    
ggsize( width = 2400, height = 450)
// Out:
//    <div id="Px1sVF"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"분단위 실시간 폐수 수질현황"
// },
// "mapping":{
// },
// "data":{
// "genName":["KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS","KR","WS"],
// "time":[1.77685686E12,1.77685686E12,1.77685704E12,1.77685704E12,1.7768574E12,1.7768574E12,1.77685776E12,1.77685776E12,1.77685812E12,1.77685812E12,1.77685848E12,1.77685848E12,1.77685878E12,1.77685878E12,1.77685914E12,1.77685914E12,1.7768595E12,1.7768595E12,1.77685986E12,1.77685986E12,1.77686016E12,1.77686016E12,1.77686052E12,1.77686052E12,1.77686082E12,1.77686082E12,1.77686118E12,1.77686118E12,1.77686154E12,1.77686154E12,1.7768619E12,1.7768619E12,1.77686226E12,1.77686226E12,1.77686262E12,1.77686262E12,1.77686292E12,1.77686292E12,1.77686328E12,1.77686328E12,1.77686364E12,1.77686364E12,1.77686394E12,1.77686394E12,1.7768643E12,1.7768643E12,1.77686466E12,1.77686466E12,1.77686496E12,1.77686496E12,1.77686532E12,1.77686532E12,1.77686568E12,1.77686568E12,1.77686598E12,1.77686598E12,1.77686634E12,1.77686634E12,1.77686664E12,1.77686664E12,1.776867E12,1.776867E12,1.77686736E12,1.77686736E12,1.77686772E12,1.77686772E12,1.77686802E12,1.77686802E12,1.77686838E12,1.77686838E12,1.77686874E12,1.77686874E12,1.77686904E12,1.77686904E12,1.7768694E12,1.7768694E12,1.7768697E12,1.7768697E12,1.77687006E12,1.77687006E12,1.77687042E12,1.77687042E12,1.77687072E12,1.77687072E12,1.77687108E12,1.77687108E12,1.77687144E12,1.77687144E12,1.77687174E12,1.77687174E12],
// "tm001":[0.0,40.8,0.0,40.8,0.0,40.8,0.0,68.2,0.0,82.2,0.0,89.2,0.0,93.6,0.0,97.1,0.0,99.7,0.0,101.7,0.0,103.0,0.0,104.1,0.0,105.4,0.0,104.8,0.0,105.9,0.0,104.5,0.0,106.3,0.0,104.5,0.0,106.1,0.0,105.0,0.0,105.0,86.0,104.8,108.0,105.2,112.0,105.7,112.0,105.4,112.0,106.8,111.0,106.1,111.0,105.9,112.0,107.2,113.0,106.8,113.0,106.6,113.0,106.1,113.0,107.7,112.0,107.7,112.0,107.5,113.0,107.0,57.0,103.0,72.0,98.8,80.0,97.9,93.0,95.6,104.0,94.5,104.0,93.8,112.0,93.8,116.0,95.8,116.0,98.8],
// "tm002":[7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.2,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,6.0,7.1,0.0,7.1,0.0,7.1,0.0,7.1,0.0,7.1,7.4,7.1,7.2,7.1,0.0,7.1,0.0,7.1,5.6,7.1,7.5,7.1,7.4,7.1,7.4,7.1,7.4,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1,7.3,7.1]
// },
// "ggsize":{
// "width":2400.0,
// "height":450.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "name":"수집시간"
// },{
// "aesthetic":"y",
// "name":"Wastewater Quality (PH)"
// },{
// "aesthetic":"color",
// "name":"발전소"
// },{
// "aesthetic":"y",
// "limits":[5.0,9.0]
// },{
// "aesthetic":"x",
// "datetime":true,
// "format":"%m-%d %H:%M"
// },{
// "aesthetic":"size",
// "name":"유량",
// "range":[0.0,15.0]
// }],
// "layers":[{
// "mapping":{
// "x":"time",
// "y":"tm002",
// "color":"genName",
// "size":"tm001"
// },
// "stat":"identity",
// "alpha":0.6,
// "position":"identity",
// "geom":"point",
// "data":{
// }
// }],
// "theme":{
// "axis_text_x":{
// "angle":45.0,
// "hjust":1.0,
// "blank":false
// }
// },
// "data_meta":{
// "series_annotations":[{
// "column":"time",
// "type":"datetime"
// },{
// "column":"tm001_time",
// "type":"datetime"
// },{
// "column":"tm002_time",
// "type":"datetime"
// }]
// }
// };
//            var plotContainer = document.getElementById("Px1sVF");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
val url = "http://192.168.35.107:7788/khnp/thermalwastewater"
val df = DataFrame.readJson(url)
df.head(5)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_117440576"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 10</p>
// <table class="dataframe" id="static_df_117440577"><thead><tr><th class="bottomBorder" style="text-align:left">time</th><th class="bottomBorder" style="text-align:left">genName</th><th class="bottomBorder" style="text-align:left">rm001</th><th class="bottomBorder" style="text-align:left">rm001_time</th><th class="bottomBorder" style="text-align:left">rm002</th><th class="bottomBorder" style="text-align:left">rm002_time</th><th class="bottomBorder" style="text-align:left">rm005</th><th class="bottomBorder" style="text-align:left">rm005_time</th><th class="bottomBorder" style="text-align:left">rm006</th><th class="bottomBorder" style="text-align:left">rm006_time</th></tr></thead><tbody><tr><td  style="vertical-align:top">2026-04-22 11:21</td><td  style="vertical-align:top">KR</td><td  style="vertical-align:top">0</td><td  style="vertical-align:top">2026-02-04 18:37</td><td  style="vertical-align:top">0</td><td  style="vertical-align:top">2026-02-04 18:37</td><td  style="vertical-align:top">0</td><td  style="vertical-align:top">2026-02-04 18:37</td><td  style="vertical-align:top">0</td><td  style="vertical-align:top">2026-02-04 18:37</td></tr><tr><td  style="vertical-align:top">2026-04-22 11:21</td><td  style="vertical-align:top">UJ</td><td  style="vertical-align:top">10.3</td><td  style="vertical-align:top">2026-04-22 11:20</td><td  style="vertical-align:top">33.6</td><td  style="vertical-align:top">2026-04-22 11:21</td><td  style="vertical-align:top">15.5</td><td  style="vertical-align:top">2026-04-22 11:21</td><td  style="verti

// %%
import kotlinx.datetime.*
import kotlin.time.Duration.Companion.minutes

val convertedDf = df.convert {
    time and rm001_time and rm002_time and rm005_time and rm006_time
}.with { 
    LocalDateTime.parse(it.toString().replace(" ", "T")).toInstant(TimeZone.UTC)
}

convertedDf.head(5)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_117440578"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 10</p>
// <table class="dataframe" id="static_df_117440579"><thead><tr><th class="bottomBorder" style="text-align:left">time</th><th class="bottomBorder" style="text-align:left">genName</th><th class="bottomBorder" style="text-align:left">rm001</th><th class="bottomBorder" style="text-align:left">rm001_time</th><th class="bottomBorder" style="text-align:left">rm002</th><th class="bottomBorder" style="text-align:left">rm002_time</th><th class="bottomBorder" style="text-align:left">rm005</th><th class="bottomBorder" style="text-align:left">rm005_time</th><th class="bottomBorder" style="text-align:left">rm006</th><th class="bottomBorder" style="text-align:left">rm006_time</th></tr></thead><tbody><tr><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">KR</td><td  style="vertical-align:top">0</td><td  style="vertical-align:top">2026-02-04T18:37:00Z</td><td  style="vertical-align:top">0</td><td  style="vertical-align:top">2026-02-04T18:37:00Z</td><td  style="vertical-align:top">0</td><td  style="vertical-align:top">2026-02-04T18:37:00Z</td><td  style="vertical-align:top">0</td><td  style="vertical-align:top">2026-02-04T18:37:00Z</td></tr><tr><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">UJ</td><td  style="vertical-align:top">10.3</td><td  style="vertical-align:top">2026-04-22T11:20:00Z</td><td  style="vertical-align:top">33.6</td><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">15.5</td><td  style="vertical-align:top">2026-0

// %%
val checkTime = 20.minutes

val finalDf = convertedDf.filter {
    (time - rm001_time).absoluteValue <= checkTime &&
    (time - rm002_time).absoluteValue <= checkTime &&
    (time - rm005_time).absoluteValue <= checkTime &&
    (time - rm006_time).absoluteValue <= checkTime
}
finalDf.head(5)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_117440580"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 10</p>
// <table class="dataframe" id="static_df_117440581"><thead><tr><th class="bottomBorder" style="text-align:left">time</th><th class="bottomBorder" style="text-align:left">genName</th><th class="bottomBorder" style="text-align:left">rm001</th><th class="bottomBorder" style="text-align:left">rm001_time</th><th class="bottomBorder" style="text-align:left">rm002</th><th class="bottomBorder" style="text-align:left">rm002_time</th><th class="bottomBorder" style="text-align:left">rm005</th><th class="bottomBorder" style="text-align:left">rm005_time</th><th class="bottomBorder" style="text-align:left">rm006</th><th class="bottomBorder" style="text-align:left">rm006_time</th></tr></thead><tbody><tr><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">UJ</td><td  style="vertical-align:top">10.3</td><td  style="vertical-align:top">2026-04-22T11:20:00Z</td><td  style="vertical-align:top">33.6</td><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">15.5</td><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">33.4</td><td  style="vertical-align:top">2026-04-22T11:21:00Z</td></tr><tr><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">WS</td><td  style="vertical-align:top">14.0</td><td  style="vertical-align:top">2026-04-22T11:20:00Z</td><td  style="vertical-align:top">34.20000076293945</td><td  style="vertical-align:top">2026-04-22T11:20:00Z</td><td  style="vertical-align:top">14.0</td><td  style="v

// %%
val data = finalDf.select{ time and genName and rm001 and rm005}
data.describe()
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_117440582"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 4, columnsCount = 10</p>
// <table class="dataframe" id="static_df_117440583"><thead><tr><th class="bottomBorder" style="text-align:left">name</th><th class="bottomBorder" style="text-align:left">type</th><th class="bottomBorder" style="text-align:left">count</th><th class="bottomBorder" style="text-align:left">unique</th><th class="bottomBorder" style="text-align:left">nulls</th><th class="bottomBorder" style="text-align:left">top</th><th class="bottomBorder" style="text-align:left">freq</th><th class="bottomBorder" style="text-align:left">min</th><th class="bottomBorder" style="text-align:left">median</th><th class="bottomBorder" style="text-align:left">max</th></tr></thead><tbody><tr><td  style="vertical-align:top">time</td><td  style="vertical-align:top">kotlinx.datetime.Instant</td><td  style="vertical-align:top">126</td><td  style="vertical-align:top">42</td><td  style="vertical-align:top">0</td><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">3</td><td  style="vertical-align:top">2026-04-22T11:21:00Z</td><td  style="vertical-align:top">2026-04-22T13:14:00Z</td><td  style="vertical-align:top">2026-04-22T15:12:00Z</td></tr><tr><td  style="vertical-align:top">genName</td><td  style="vertical-align:top">String</td><td  style="vertical-align:top">126</td><td  style="vertical-align:top">3</td><td  style="vertical-align:top">0</td><td  style="vertical-align:top">UJ</td><td  style="vertical-align:top">42</td><td  style="vertical-align:top">UJ</td><td  style="vertical-align:top">WS</td><td  style="vertical-align:top"

// %%
import kotlin.math.round

val data = finalDf.select{ time and genName and rm001 and rm005}
    .convert{ rm001 and rm005}.with {
        val value = it?.toString()?.toDoubleOrNull() ?: 0.0
        round(value * 10) / 10.0
}.toMap()


letsPlot(data) +
geomRibbon(
    alpha = 0.2,
          // 툴팁 설정 추가
    tooltips = layerTooltips()
        .title("@genName")              // 툴팁 제목에 발전소 이름 표시
        .line("시간|@time")             // '라벨|값' 형식으로 표시
        .line("취수 수온|@rm001 °C")
        .line("배수 수온|@rm005 °C")
        .format("@time", "%m-%d %H:%M") // 시간 형식 지정
        .format("@rm001", ".1f")        // 소수점 첫째 자리까지 표시
        .format("@rm005", ".1f")
          ){
    x="time"
    ymin = "rm001"
    ymax = "rm005"
    fill = "genName"
} +
scaleYContinuous(limits=Pair(5.0,25.0)) +    
scaleXDateTime(  
    format = "%m-%d %H:%M" ,
            // 데이터의 'time' 컬럼에 있는 모든 값을 그리드 위치로 지정
    breaks = data["time"] as List<*> 
) +
labs( title = "발전소별 실시간 취수/배수 수온 현황", y="수온(°C)", x="수집시간", fill="발전소") +  
theme(
    axisTextX= elementText( angle=45),
    // X축 주요 그리드 선 설정 (색상, 두께 등)
        panelGridMajorX = elementLine(color = "#e0e0e0", size = 0.5),

   
) +
ggsize(2400, 600)
// Out:
//    <div id="4IShqq"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"발전소별 실시간 취수/배수 수온 현황"
// },
// "mapping":{
// },
// "data":{
// "rm005":[15.5,14.0,23.0,15.6,14.0,23.0,15.6,14.0,23.1,15.4,14.0,23.1,15.6,14.0,23.1,15.5,14.0,23.1,15.4,14.0,23.3,15.3,14.0,23.2,15.5,14.1,23.3,15.3,14.1,23.3,15.3,14.1,23.3,15.4,14.1,23.3,15.5,14.1,23.4,15.2,14.1,23.6,15.4,14.1,23.5,15.4,14.1,23.5,15.4,14.1,23.7,15.5,14.1,23.7,15.2,14.2,23.7,15.3,14.2,23.8,15.3,14.2,23.8,15.4,14.2,23.8,15.1,14.2,24.0,15.2,14.2,23.9,15.1,14.2,23.9,15.1,14.2,24.0,15.1,14.2,24.0,15.1,14.3,24.0,15.2,14.3,24.0,15.1,14.3,24.1,15.2,14.3,24.0,15.0,14.3,24.0,15.1,14.3,24.1,15.2,14.3,24.0,14.9,14.3,24.0,14.9,14.3,24.0,15.0,14.3,24.1,14.9,14.3,24.1,14.7,14.4,24.1,14.9,14.4,24.2,14.7,14.4,24.0,15.0,14.4,24.2],
// "genName":["UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK","UJ","WS","YK"],
// "time":[1.77685686E12,1.77685686E12,1.77685686E12,1.77685704E12,1.77685704E12,1.77685704E12,1.77685746E12,1.77685746E12,1.77685746E12,1.77685776E12,1.77685776E12,1.77685776E12,1.77685812E12,1.77685812E12,1.77685812E12,1.77685848E12,1.77685848E12,1.77685848E12,1.77685878E12,1.77685878E12,1.77685878E12,1.77685914E12,1.77685914E12,1.77685914E12,1.7768595E12,1.7768595E12,1.7768595E12,1.77685986E12,1.77685986E12,1.77685986E12,1.77686016E12,1.77686016E12,1.77686016E12,1.77686052E12,1.77686052E12,1.77686052E12,1.77686082E12,1.77686082E12,1.77686082E12,1.77686118E12,1.77686118E12,1.77686118E12,1.77686154E12,1.77686154E12,1.77686154E12,1.77686196E12,1.77686196E12,1.77686196E12,1.77686226E12,1.77686226E12,1.77686226E12,1.77686262E12,1.77686262E12,1.77686262E12,1.77686292E12,1.77686292E12,1.77686292E12,1.77686328E12,1.77686328E12,1.77686328E12,1.77686364E12,1.77686364E12,1.77686364E12,1.77686394E12,1.77686394E12,1.77686394E12,1.7768643E12,1.7768643E12,1.7768643E12,1.77686466E12,1.77686466E12,1.77686466E12,1.77686502E12,1.77686502E12,1.77686502E12,1.77686532E12,1.77686532E12,1.77686532E12,1.77686568E12,1.77686568E12,1.77686568E12,1.77686598E12,1.77686598E12,1.77686598E12,1.77686634E12,1.77686634E12,1.77686634E12,1.7768667E12,1.7768667E12,1.7768667E12,1.776867E12,1.776867E12,1.776867E12,1.77686736E12,1.77686736E12,1.77686736E12,1.77686772E12,1.77686772E12,1.77686772E12,1.77686802E12,1.77686802E12,1.77686802E12,1.77686838E12,1.77686838E12,1.77686838E12,1.77686874E12,1.77686874E12,1.77686874E12,1.77686904E12,1.77686904E12,1.77686904E12,1.7768694E12,1.7768694E12,1.7768694E12,1.77686976E12,1.77686976E12,1.77686976E12,1.77687006E12,1.77687006E12,1.77687006E12,1.77687042E12,1.77687042E12,1.77687042E12,1.77687072E12,1.77687072E12,1.77687072E12],
// "rm001":[10.3,14.0,16.1,10.3,14.0,16.1,10.3,14.0,16.1,10.2,14.0,16.1,10.2,14.1,16.1,10.2,14.1,16.2,10.3,14.1,16.2,10.3,14.1,16.2,10.3,14.1,16.2,10.2,14.1,16.2,10.3,14.1,16.2,10.2,14.2,16.2,10.3,14.2,16.2,10.3,14.2,16.2,10.3,14.2,16.2,10.4,14.2,16.2,10.3,14.2,16.2,10.3,14.2,16.2,10.3,14.3,16.2,10.2,14.3,16.2,10.2,14.3,16.2,10.2,14.3,16.3,10.3,14.3,16.3,10.3,14.3,16.3,10.1,14.3,16.3,10.2,14.3,16.3,10.1,14.3,16.4,10.0,14.3,16.4,10.1,14.3,16.4,10.0,14.3,16.3,10.0,14.3,16.5,9.8,14.3,16.5,9.9,14.3,16.5,9.8,14.3,16.6,9.8,14.3,16.6,9.8,14.3,16.6,9.8,14.3,16.6,9.8,14.3,16.6,9.9,14.3,16.7,9.8,14.3,16.8,9.6,14.3,16.7,9.7,14.3,16.8]
// },
// "ggsize":{
// "width":2400.0,
// "height":600.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "limits":[5.0,25.0]
// },{
// "aesthetic":"x",
// "datetime":true,
// "breaks":[1776856860000,1776856860000,1776856860000,1776857040000,1776857040000,1776857040000,1776857460000,1776857460000,1776857460000,1776857760000,1776857760000,1776857760000,1776858120000,1776858120000,1776858120000,1776858480000,1776858480000,1776858480000,1776858780000,1776858780000,1776858780000,1776859140000,1776859140000,1776859140000,1776859500000,1776859500000,1776859500000,1776859860000,1776859860000,1776859860000,1776860160000,1776860160000,1776860160000,1776860520000,1776860520000,1776860520000,1776860820000,1776860820000,1776860820000,1776861180000,1776861180000,1776861180000,1776861540000,1776861540000,1776861540000,1776861960000,1776861960000,1776861960000,1776862260000,1776862260000,1776862260000,1776862620000,1776862620000,1776862620000,1776862920000,1776862920000,1776862920000,1776863280000,1776863280000,1776863280000,1776863640000,1776863640000,1776863640000,1776863940000,1776863940000,1776863940000,1776864300000,1776864300000,1776864300000,1776864660000,1776864660000,1776864660000,1776865020000,1776865020000,1776865020000,1776865320000,1776865320000,1776865320000,1776865680000,1776865680000,1776865680000,1776865980000,1776865980000,1776865980000,1776866340000,1776866340000,1776866340000,1776866700000,1776866700000,1776866700000,1776867000000,1776867000000,1776867000000,1776867360000,1776867360000,1776867360000,1776867720000,1776867720000,1776867720000,1776868020000,1776868020000,1776868020000,1776868380000,1776868380000,1776868380000,1776868740000,1776868740000,1776868740000,1776869040000,1776869040000,1776869040000,1776869400000,1776869400000,1776869400000,1776869760000,1776869760000,1776869760000,1776870060000,1776870060000,1776870060000,1776870420000,1776870420000,1776870420000,1776870720000,1776870720000,1776870720000],
// "format":"%m-%d %H:%M"
// },{
// "aesthetic":"x",
// "name":"수집시간"
// },{
// "aesthetic":"y",
// "name":"수온(°C)"
// },{
// "aesthetic":"fill",
// "name":"발전소"
// }],
// "layers":[{
// "mapping":{
// "x":"time",
// "ymin":"rm001",
// "ymax":"rm005",
// "fill":"genName"
// },
// "stat":"identity",
// "alpha":0.2,
// "position":"identity",
// "geom":"ribbon",
// "tooltips":{
// "title":"@genName",
// "lines":["시간|@time","취수 수온|@rm001 °C","배수 수온|@rm005 °C"],
// "formats":[{
// "field":"@time",
// "format":"%m-%d %H:%M"
// },{
// "field":"@rm001",
// "format":".1f"
// },{
// "field":"@rm005",
// "format":".1f"
// }]
// },
// "data":{
// }
// }],
// "theme":{
// "panel_grid_major_x":{
// "color":"#e0e0e0",
// "size":0.5,
// "blank":false
// },
// "axis_text_x":{
// "angle":45.0,
// "blank":false
// }
// },
// "data_meta":{
// "series_annotations":[{
// "column":"time",
// "type":"datetime"
// }]
// }
// };
//            var plotContainer = document.getElementById("4IShqq");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
