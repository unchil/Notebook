# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
serviceKeyFilePath = "/Volumes/WorkSpace/Notebook/data/OceanMensurationService.json"

# %%
serviceInfo = pd.read_json(serviceKeyFilePath)

# %%
codeUrl = serviceInfo.endpoint_json[0] + "?key=" + serviceInfo.key[0] + "&id=" + serviceInfo.code[0]
codeRawDf = pd.read_json(codeUrl, encoding='euc-kr')
codeRawDf
# Out:
#                                                          body   header
# item        [{'bld_dat': '2024-05-13', 'lon': '126.7364', ...      NaN
# resultMsg                                                 NaN  success
# resultCode                                                NaN       00

# %%
codeList = []
for data in codeRawDf.stack().iloc[0]:
    codeList.append(pd.DataFrame.from_dict(data,  orient='index').T)

codeDf = pd.concat(codeList).reset_index()
codeDf
# Out:
#     index     bld_dat       lon sta_nam_kor bot_dep gru_nam sur_dep  \
# 0       0  2024-05-13  126.7364       완도 대창    None      남해       3
# 1       0  2024-05-13  127.0837       완도 사동    None      남해       3
# 2       0  2024-05-09  127.0101       완도 감목    None      남해       5
# 3       0  2024-03-11  128.5239       고성 가진      28      동해       5
# 4       0  2020-05-28   126.147      태안 파도리    None      서해     1.5
# ..    ...         ...       ...         ...     ...     ...     ...
# 79      0  2004-04-09  125.4851     목포(등부표)    None      서해       5
# 80      0  2004-02-12   126.187         추자도    None      남해       5
# 81      0  2004-02-10  127.3509          고흥    None      남해       5
# 82      0  2004-01-02  128.2285          통영    None      남해       5
# 83      0  2003-11-25  127.5308          여수    None      남해       5
#
#    mid_tmp_yn sta_cde             sta_des     end_dat sur_tmp_yn bot_tmp_yn  \
# 0           N   fwdo5                None        None          Y          N
# 1           N   fwso5                None        None          Y          N
# 2           N   fwyo5                None        None          Y          N
# 3           Y   fggo3                None        None          Y          Y
# 4           Y   ftpk5          태안군청 신규관측소        None          Y          N
# ..        ...     ...                 ...         ...        ...        ...
# 79          N   mp001      전남 신안군 도초면 도초도  2005-04-17          N          N
# 80          N   jj001        제주시 북제주군 추자도  2006-03-01          N          N
# 81          N   ys002         전남 고흥군 외나로도  2005-01-20          N          N
# 82          N   ms001  경남 통영시 욕지면 연화리 연화도  2005-09-23          N          N
# 83          N   ys001          전남 여수시 국동항  2008-05-26          N          N
#
#         lat mid_dep
# 0   34.3825    None
# 1   34.3373    None
# 2    34.342    None
# 3   38.3681      15
# 4   36.7123     2.5
# ..      ...     ...
# 79   34.364    None
# 80  33.5764    None
# 81  34.2612    None
# 82  34.3961    None
# 83   34.417    None
#
# [84 rows x 15 columns]

# %%
listUrl = serviceInfo.endpoint_json[0] + "?key=" + serviceInfo.key[0] + "&id=" + serviceInfo.list[0]
listRawDf = pd.read_json(listUrl, encoding='euc-kr')
listRawDf
# Out:
#                                                          body   header
# item        [{'sta_nam_kor': '기장', 'wtr_tmp': '11.7', 'obs...      NaN
# resultMsg                                                 NaN  success
# resultCode                                                NaN       00

# %%
listList = []
for data in listRawDf.stack().iloc[0]:
    listList.append(pd.DataFrame.from_dict(data,  orient='index').T)

listDf = pd.concat(listList).reset_index()
listDf
# Out:
#     index sta_nam_kor wtr_tmp obs_lay repair_gbn   obs_tim   dox sta_cde  \
# 0       0          기장    11.7       1          1  11:30:00  None   bgj8a
# 1       0          기장    11.8       2          1  11:30:00  None   bgj8a
# 2       0          기장    11.8       3          1  11:30:00  None   bgj8a
# 3       0          강릉     7.2       1          1  11:30:00  None   bgna3
# 4       0          강릉     7.1       2          1  11:30:00  None   bgna3
# ..    ...         ...     ...     ...        ...       ...   ...     ...
# 66      0       통영 영운     8.5       1          1  11:30:00  None   ty004
# 67      0       통영 사량     7.4       1          1  11:30:00  10.3   ty005
# 68      0       완도 청산     8.1       1          1  11:30:00  10.1   wc001
# 69      0       완도 금일     7.8       1          1  11:30:00  None   wk094
# 70      0      완도 노화도     6.9       1          1  11:30:00  None   wn087
#
#      sal     obs_dat
# 0   None  2025-02-26
# 1   None  2025-02-26
# 2   None  2025-02-26
# 3   None  2025-02-26
# 4   None  2025-02-26
# ..   ...         ...
# 66  None  2025-02-26
# 67  None  2025-02-26
# 68  None  2025-02-26
# 69  None  2025-02-26
# 70  None  2025-02-26
#
# [71 rows x 10 columns]

# %%
listDf['date'] = pd.to_datetime(listDf.obs_dat + ' ' +listDf.obs_tim , format='%Y-%m-%d %H:%M:%S')

# %%
df = listDf.merge(codeDf, how='left', on='sta_cde')
df
# Out:
#     index_x sta_nam_kor_x wtr_tmp obs_lay repair_gbn   obs_tim   dox sta_cde  \
# 0         0            기장    11.7       1          1  11:30:00  None   bgj8a
# 1         0            기장    11.8       2          1  11:30:00  None   bgj8a
# 2         0            기장    11.8       3          1  11:30:00  None   bgj8a
# 3         0            강릉     7.2       1          1  11:30:00  None   bgna3
# 4         0            강릉     7.1       2          1  11:30:00  None   bgna3
# ..      ...           ...     ...     ...        ...       ...   ...     ...
# 66        0         통영 영운     8.5       1          1  11:30:00  None   ty004
# 67        0         통영 사량     7.4       1          1  11:30:00  10.3   ty005
# 68        0         완도 청산     8.1       1          1  11:30:00  10.1   wc001
# 69        0         완도 금일     7.8       1          1  11:30:00  None   wk094
# 70        0        완도 노화도     6.9       1          1  11:30:00  None   wn087
#
#      sal     obs_dat  ...  bot_dep gru_nam sur_dep mid_tmp_yn  \
# 0   None  2025-02-26  ...       15      동해       5          Y
# 1   None  2025-02-26  ...       15      동해       5          Y
# 2   None  2025-02-26  ...       15      동해       5          Y
# 3   None  2025-02-26  ...       30      동해       5          Y
# 4   None  2025-02-26  ...       30      동해       5          Y
# ..   ...         ...  ...      ...     ...     ...        ...
# 66  None  2025-02-26  ...     None      남해       5          N
# 67  None  2025-02-26  ...     None      남해       5          N
# 68  None  2025-02-26  ...     None      남해       3          N
# 69  None  2025-02-26  ...     None      남해     3.5          N
# 70  None  2025-02-26  ...     None      남해       5          N
#
#                        sta_des end_dat sur_tmp_yn bot_tmp_yn      lat mid_dep
# 0                         None    None          Y          Y   35.187      10
# 1                         None    None          Y          Y   35.187      10
# 2                         None    None          Y          Y   35.187      10
# 3              강원도 강릉시 사천면 사천항    None          Y          Y   37.799      20
# 4              강원도 강릉시 사천면 사천항    None          Y          Y   37.799      20
# ..                         ...     ...        ...        ...      ...     ...
# 66  경남 통영시 산양면 영운리 양식환경연구소 ...    None          Y          N  34.7904    None
# 67            경상남도 통영시 사량면 양지리    None          Y          N  34.8022    None
# 68            전라남도 완도군 청산면 도락리    None          Y          N  34.1698    None
# 69              전남 완도군 금일읍 충동리    None          Y          N  34.3786    None
# 70                      완도 노화도    None          Y          N  34.2214    None
#
# [71 rows x 24 columns]

# %%
df = df.astype({'wtr_tmp':'float64'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index_x        71 non-null     int64
#  1   sta_nam_kor_x  71 non-null     object
#  2   wtr_tmp        71 non-null     float64
#  3   obs_lay        71 non-null     object
#  4   repair_gbn     71 non-null     object
#  5   obs_tim        71 non-null     object
#  6   dox            15 non-null     object
#  7   sta_cde        71 non-null     object
#  8   sal            2 non-null      object
#  9   obs_dat        71 non-null     object
#  10  index_y        71 non-null     int64
#  11  bld_dat        71 non-null     object
#  12  lon            71 non-null     object
#  13  sta_nam_kor_y  71 non-null     object
#  14  bot_dep        21 non-null     object
#  15  gru_nam        71 non-null     object
#  16  sur_dep        71 non-null     object
#  17  mid_tmp_yn     71 non-null     object
#  18  sta_des        56 non-null     object
#  19  end_dat        0 non-null      object
#  20  sur_tmp_yn     71 non-null     object
#  21  bot_tmp_yn     71 non-null     object
#  22  lat            71 non-null     object
#  23  mid_dep        47 non-null     object
# dtypes: float64(1), int64(2), object(21)
# memory usage: 13.4+ KB

# %%
df.loc[(df.gru_nam == '동해') & (df.obs_lay == '1') ][['sta_nam_kor_x', 'wtr_tmp']].plot.bar( x='sta_nam_kor_x', xlabel="관측지점", ylabel="온도")
# Out:
# <Axes: xlabel='관측지점', ylabel='온도'>

# %%
df.loc[(df.gru_nam == '서해') & (df.obs_lay == '1') ][['sta_nam_kor_x', 'wtr_tmp']].plot.bar( x='sta_nam_kor_x', xlabel="관측지점", ylabel="온도")
# Out:
# <Axes: xlabel='관측지점', ylabel='온도'>

# %%
df.loc[(df.gru_nam == '남해') & (df.obs_lay == '1') ][['sta_nam_kor_x', 'wtr_tmp']].plot.bar( x='sta_nam_kor_x', xlabel="관측지점", ylabel="온도")
# Out:
# <Axes: xlabel='관측지점', ylabel='온도'>
