// %%
%useLatestDescriptors
%use dataframe

// %%
USE {
    repositories {
        mavenCentral()
    }
    dependencies{
        implementation("org.xerial:sqlite-jdbc:3.45.1.0")
    }
}

// %%
USE{
    dependencies("org.xerial:sqlite-jdbc:3.45.1.0")
}

// %%
import java.sql.DriverManager
import java.util.*

// %%
val dbConfig = DbConnectionConfig("jdbc:sqlite:/Volumes/WorkSpace/Notebook/db.sqlite")

// %%
val dataschemas = DataFrame.getSchemaForAllSqlTables(dbConfig)
